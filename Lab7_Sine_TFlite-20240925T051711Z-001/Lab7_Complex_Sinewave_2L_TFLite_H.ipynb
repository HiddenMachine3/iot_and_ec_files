# %%
# TensorFlow is an open source machine learning library
import tensorflow as tf

# NumPy is a math library
import numpy as np

# Matplotlib is a graphing library
import matplotlib.pyplot as plt

# math is Python's math library
import math

# We'll use Keras to create a simple model architecture
# Note: Changed tf.keras below to tensorflow.keras (code from the book)
from tensorflow.keras import layers

# Define the number of nodes in each layer of the network
# Layer1 with 24 and Layer2 with 16 nodes is better than 16 and 24 respectively.
DENSE1_SIZE = 32
DENSE2_SIZE = 16
NUM_OF_EPOCHS = 900  # Changed 1500 to 900 because no change in loss after 800
BATCH_SIZE = 16

# We'll generate this many sample datapoints
SAMPLES = 1200
# Set a "seed" value, so we get the same random numbers each time we run this
# notebook. Any number can be used here.
SEED = 1337
np.random.seed(SEED)
tf.random.set_seed(SEED)
# Generate a uniformly distributed set of random numbers in the range from
# 0 to 2π, which covers a complete sine wave oscillation
# You can generate only a half of the sine wave by changing high from 2pi to pi
x_values = np.random.uniform(low=0, high=2 * math.pi, size=SAMPLES)
# Shuffle the values to guarantee they're not in order
np.random.shuffle(x_values)
# Calculate the corresponding sine values
y_values = 5 * np.sin(x_values) ** 2 + 4 * np.cos(x_values)  # np.sin(x_values)
# Plot our data. The 'b.' argument tells the library to print blue dots.
plt.plot(x_values, y_values, "b.")
plt.show()

# Add a small random number to each y value
# When the number of Layer 1 and 2 nodes are increased, the noise level
# from 0.001 to some higher value (0.01, etc) still impacts less the quality
# of predictions.
y_values += 0.1 * np.random.randn(*y_values.shape)
# Plot our data
plt.plot(x_values, y_values, "b.")
plt.show()

# We'll use 60% of our data for training and 20% for testing. The remaining 20%
# will be used for validation. Calculate the indices of each section.
TRAIN_SPLIT = int(0.6 * SAMPLES)
TEST_SPLIT = int(0.2 * SAMPLES + TRAIN_SPLIT)
# Use np.split to chop our data into three parts.
# The second argument to np.split is an array of indices where the data will be
# split. We provide two indices, so the data will be divided into three chunks.
x_train, x_validate, x_test = np.split(x_values, [TRAIN_SPLIT, TEST_SPLIT])
y_train, y_validate, y_test = np.split(y_values, [TRAIN_SPLIT, TEST_SPLIT])
# Double check that our splits add up correctly
assert (x_train.size + x_validate.size + x_test.size) == SAMPLES

# Plot the data in each partition in different colors:
plt.plot(x_train, y_train, "b.", label="Train")
plt.plot(x_validate, y_validate, "y.", label="Validate")
plt.plot(x_test, y_test, "r.", label="Test")
plt.legend()
plt.show()


# Activation function used here is relu (Rectified Linear Unit)
def relu(input):
    return max(0.0, input)


model_2 = tf.keras.Sequential()
# First layer takes a scalar input and feeds it through 16 "neurons." The
# neurons decide whether to activate based on the 'relu' activation function.
model_2.add(layers.Dense(DENSE1_SIZE, activation="relu", input_shape=(1,)))
# The new second layer may help the network learn more complex representations
model_2.add(layers.Dense(DENSE2_SIZE, activation="relu"))
# Final layer is a single neuron, since we want to output a single value
model_2.add(layers.Dense(1))
# Compile the model using a standard optimizer and loss function for regression
model_2.compile(optimizer="rmsprop", loss="mse", metrics=["mae"])
# Show a summary of the model
model_2.summary()
# Out:
# d:\opt\WingetApps_Ddrive\anaconda\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 32)             │            64 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 609 (2.38 KB)
#  Trainable params: 609 (2.38 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# 0. Did not get the same accurate predection as shown in the book epochs=600
# 1. So, increased the epochs from 600 to 1000 to see if there is any improvement
# Saw a great improvment on the negative cycle, which was closer to actual
# 2. Increased the epochs still further from 1000 to 1200 to see if it improves further
# 3. Still some error near negative peak, so changed it from 1200 to 1500
# 4. So far, the batch size was kept at 16. Now epochs=1500 and batch_size=32 tried out
# The previous run +v peak also got affected a bit, but -ve peak became better
# 5. Change now epochs=1500 and batch_size=64, it became worse.
# 6. Went back to epochs=1500 and batch_size=16
# 7. Error does not improve beyond Epoch=1000, so reduced it from 1500 to 1000
history_2 = model_2.fit(x_train, y_train, epochs=NUM_OF_EPOCHS, batch_size=BATCH_SIZE,
validation_data=(x_validate, y_validate))
# Out:
# Epoch 1/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 15.7035 - mae: 3.6712 - val_loss: 11.6582 - val_mae: 3.1129
# Epoch 2/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.7892 - mae: 3.0459 - val_loss: 11.2528 - val_mae: 3.0083
# Epoch 3/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.4046 - mae: 2.9655 - val_loss: 11.1477 - val_mae: 2.9990
# Epoch 4/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 11.1672 - mae: 2.9401 - val_loss: 11.0665 - val_mae: 2.9953
# Epoch 5/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.9524 - mae: 2.9175 - val_loss: 11.0009 - val_mae: 2.9929
# Epoch 6/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.7557 - mae: 2.8957 - val_loss: 10.9520 - val_mae: 2.9917
# Epoch 7/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.5788 - mae: 2.8753 - val_loss: 10.9178 - val_mae: 2.9909
# Epoch 8/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.4215 - mae: 2.8562 - val_loss: 10.8977 - val_mae: 2.9906
# Epoch 9/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.
900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8544 - mae: 1.7632 - val_loss: 5.5907 - val_mae: 2.0258
# Epoch 181/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5562 - mae: 1.7011 - val_loss: 5.2228 - val_mae: 1.9540
# Epoch 182/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2624 - mae: 1.6429 - val_loss: 4.8431 - val_mae: 1.8734
# Epoch 183/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9691 - mae: 1.5857 - val_loss: 4.4806 - val_mae: 1.7986
# Epoch 184/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6877 - mae: 1.5312 - val_loss: 4.1331 - val_mae: 1.7276
# Epoch 185/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4063 - mae: 1.4761 - val_loss: 3.7623 - val_mae: 1.6449
# Epoch 186/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1103 - mae: 1.4142 - val_loss: 3.3991 - val_mae: 1.5612
# Epoch 187/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8305 - mae: 1.3534 - val_loss: 3.0542 - val_mae: 1.4738
# Epoch 188/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.5618 - mae: 1.2902 - val_loss: 2.7408 - val_mae: 1.3919
# Epoch 189/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3138 - mae: 1.2302 - val_loss: 2.4595 - val_mae: 1.3172
# Epoch 190/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0966 - mae: 1.1759 - val_loss: 2.2144 - val_mae: 1.2464
# Epoch 191/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9027 - mae: 1.1215 - val_loss: 1.9997 - val_mae: 1.1776
# Epoch 192/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7351 - mae: 1.0688 - val_loss: 1.8079 - val_mae: 1.1094
# Epoch 193/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5893 - mae: 1.0176 - val_loss: 1.6428 - val_mae: 1.0441
# Epoch 194/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4606 - mae: 0.9670 - val_loss: 1.4953 - val_mae: 0.9801
# Epoch 195/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3502 - mae: 0.9189 - val_loss: 1.3707 - val_mae: 0.9207
# Epoch 196/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2585 - mae: 0.8741 - val_loss: 1.2552 - val_mae: 0.8641
# Epoch 197/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.1821 - mae: 0.8345 - val_loss: 1.1773 - val_mae: 0.8203
# Epoch 198/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1207 - mae: 0.7998 - val_loss: 1.1039 - val_mae: 0.7807
# Epoch 199/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0667 - mae: 0.7707 - val_loss: 1.0339 - val_mae: 0.7462
# Epoch 200/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0163 - mae: 0.7447 - val_loss: 0.9742 - val_mae: 0.7181
# Epoch 201/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9726 - mae: 0.7219 - val_loss: 0.9192 - val_mae: 0.6929
# Epoch 202/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9325 - mae: 0.7005 - val_loss: 0.8843 - val_mae: 0.6718
# Epoch 203/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8971 - mae: 0.6773 - val_loss: 0.8358 - val_mae: 0.6449
# Epoch 204/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8626 - mae: 0.6564 - val_loss: 0.7961 - val_mae: 0.6215
# Epoch 205/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8297 - mae: 0.6388 - val_loss: 0.7580 - val_mae: 0.6017
# Epoch 206/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.7988 - mae: 0.6233 - val_loss: 0.7212 - val_mae: 0.5832
# Epoch 207/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.7689 - mae: 0.6092 - val_loss: 0.6870 - val_mae: 0.5661
# Epoch 208/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.7395 - mae: 0.5956 - val_loss: 0.6550 - val_mae: 0.5502
# Epoch 209/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7117 - mae: 0.5825 - val_loss: 0.6232 - val_mae: 0.5346
# Epoch 210/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6833 - mae: 0.5689 - val_loss: 0.5918 - val_mae: 0.5190
# Epoch 211/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6553 - mae: 0.5554 - val_loss: 0.5631 - val_mae: 0.5038
# Epoch 212/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6279 - mae: 0.5412 - val_loss: 0.5353 - val_mae: 0.4889
# Epoch 213/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6006 - mae: 0.5265 - val_loss: 0.5076 - val_mae: 0.4736
# Epoch 214/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.
900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0253 - mae: 0.1185 - val_loss: 0.0141 - val_mae: 0.0924
# Epoch 392/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0250 - mae: 0.1180 - val_loss: 0.0144 - val_mae: 0.0936
# Epoch 393/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0252 - mae: 0.1184 - val_loss: 0.0139 - val_mae: 0.0918
# Epoch 394/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0247 - mae: 0.1174 - val_loss: 0.0140 - val_mae: 0.0922
# Epoch 395/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0247 - mae: 0.1176 - val_loss: 0.0140 - val_mae: 0.0921
# Epoch 396/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0246 - mae: 0.1174 - val_loss: 0.0140 - val_mae: 0.0920
# Epoch 397/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0245 - mae: 0.1174 - val_loss: 0.0136 - val_mae: 0.0904
# Epoch 398/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0231 - mae: 0.1145 - val_loss: 0.0134 - val_mae: 0.0897
# Epoch 399/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0233 - mae: 0.1168 - val_loss: 0.0142 - val_mae: 0.0938
# Epoch 400/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0218 - mae: 0.1131 - val_loss: 0.0151 - val_mae: 0.0963
# Epoch 401/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0216 - mae: 0.1122 - val_loss: 0.0135 - val_mae: 0.0900
# Epoch 402/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0275 - mae: 0.1296 - val_loss: 0.0134 - val_mae: 0.0903
# Epoch 403/900
# ...
# Epoch 768/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0240 - mae: 0.1205 - val_loss: 0.0143 - val_mae: 0.0935
# Epoch 769/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0209 - mae: 0.1104 - val_loss: 0.0170 - val_mae: 0.1034
# Epoch 770/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0232 - mae: 0.1186 - val_loss: 0.0137 - val_mae: 0.0909
# Epoch 771/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0227 - mae: 0.1170 - val_loss: 0.0135 - val_mae: 0.0903
# Epoch 772/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0240 - mae: 0.1205 - val_loss: 0.0143 - val_mae: 0.0936
# Epoch 773/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0209 - mae: 0.1103 - val_loss: 0.0171 - val_mae: 0.1035
# Epoch 774/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0232 - mae: 0.1186 - val_loss: 0.0137 - val_mae: 0.0910
# Epoch 775/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0225 - mae: 0.1165 - val_loss: 0.0136 - val_mae: 0.0903
# Epoch 776/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0240 - mae: 0.1206 - val_loss: 0.0143 - val_mae: 0.0935
# Epoch 777/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0210 - mae: 0.1105 - val_loss: 0.0166 - val_mae: 0.1021
# Epoch 778/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0231 - mae: 0.1179 - val_loss: 0.0137 - val_mae: 0.0911
# Epoch 779/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0227 - mae: 0.1172 - val_loss: 0.0136 - val_mae: 0.0907
# Epoch 780/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0238 - mae: 0.1199 - val_loss: 0.0142 - val_mae: 0.0933
# Epoch 781/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0209 - mae: 0.1106 - val_loss: 0.0163 - val_mae: 0.1012
# Epoch 782/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0230 - mae: 0.1174 - val_loss: 0.0138 - val_mae: 0.0913
# Epoch 783/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0210 - mae: 0.1104 - val_loss: 0.0137 - val_mae: 0.0913
# Epoch 784/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0226 - mae: 0.1174 - val_loss: 0.0137 - val_mae: 0.0910
# Epoch 785/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0235 - mae: 0.1191 - val_loss: 0.0142 - val_mae: 0.0931
# Epoch 786/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0211 - mae: 0.1112 - val_loss: 0.0160 - val_mae: 0.0999
# Epoch 787/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0229 - mae: 0.1165 - val_loss: 0.0138 - val_mae: 0.0915
# Epoch 788/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0215 - mae: 0.1134 - val_loss: 0.0141 - val_mae: 0.0929
# Epoch 789/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0205 - mae: 0.1097 - val_loss: 0.0171 - val_mae: 0.1037
# Epoch 790/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0232 - mae: 0.1186 - val_loss: 0.0138 - val_mae: 0.0913
# Epoch 791/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0224 - mae: 0.1158 - val_loss: 0.0135 - val_mae: 0.0901
# Epoch 792/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0241 - mae: 0.1210 - val_loss: 0.0139 - val_mae: 0.0917
# Epoch 793/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0231 - mae: 0.1180 - val_loss: 0.0146 - val_mae: 0.0948
# Epoch 794/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0208 - mae: 0.1098 - val_loss: 0.0145 - val_mae: 0.0946
# Epoch 795/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0221 - mae: 0.1131 - val_loss: 0.0136 - val_mae: 0.0903
# Epoch 796/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0237 - mae: 0.1192 - val_loss: 0.0139 - val_mae: 0.0916
# Epoch 797/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0231 - mae: 0.1179 - val_loss: 0.0144 - val_mae: 0.0941
# Epoch 798/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0200 - mae: 0.1081 - val_loss: 0.0165 - val_mae: 0.1021
# Epoch 799/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 0.0228 - mae: 0.1166 - val_loss: 0.0141 - val_mae: 0.0926
# Epoch 800/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0208 - mae: 0.1104 - val_loss: 0.0143 - val_mae: 0.0939
# Epoch 801/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0219 - mae: 0.1130 - val_loss: 0.0137 - val_mae: 0.0910
# Epoch 802/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0229 - mae: 0.1176 - val_loss: 0.0137 - val_mae: 0.0911
# Epoch 803/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0234 - mae: 0.1188 - val_loss: 0.0143 - val_mae: 0.0935
# Epoch 804/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0209 - mae: 0.1105 - val_loss: 0.0173 - val_mae: 0.1044
# Epoch 805/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0232 - mae: 0.1187 - val_loss: 0.0138 - val_mae: 0.0915
# Epoch 806/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0207 - mae: 0.1097 - val_loss: 0.0135 - val_mae: 0.0902
# Epoch 807/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0237 - mae: 0.1198 - val_loss: 0.0140 - val_mae: 0.0923
# Epoch 808/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0216 - mae: 0.1137 - val_loss: 0.0148 - val_mae: 0.0958
# Epoch 809/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0216 - mae: 0.1117 - val_loss: 0.0139 - val_mae: 0.0918
# Epoch 810/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0214 - mae: 0.1133 - val_loss: 0.0137 - val_mae: 0.0910
# Epoch 811/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0232 - mae: 0.1185 - val_loss: 0.0139 - val_mae: 0.0918
# Epoch 812/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - loss: 0.0225 - mae: 0.1164 - val_loss: 0.0144 - val_mae: 0.0940
# Epoch 813/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 84ms/step - loss: 0.0191 - mae: 0.1065 - val_loss: 0.0152 - val_mae: 0.0970
# Epoch 814/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 0.0229 - mae: 0.1141 - val_loss: 0.0137 - val_mae: 0.0913
# Epoch 815/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.0225 - mae: 0.1172 - val_loss: 0.0140 - val_mae: 0.0925
# Epoch 816/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0209 - mae: 0.1115 - val_loss: 0.0161 - val_mae: 0.1005
# Epoch 817/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0231 - mae: 0.1175 - val_loss: 0.0137 - val_mae: 0.0910
# Epoch 818/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0230 - mae: 0.1179 - val_loss: 0.0138 - val_mae: 0.0914
# Epoch 819/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.0231 - mae: 0.1181 - val_loss: 0.0145 - val_mae: 0.0944
# Epoch 820/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0204 - mae: 0.1084 - val_loss: 0.0143 - val_mae: 0.0936
# Epoch 821/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0218 - mae: 0.1129 - val_loss: 0.0136 - val_mae: 0.0906
# Epoch 822/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0234 - mae: 0.1187 - val_loss: 0.0139 - val_mae: 0.0917
# Epoch 823/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - loss: 0.0227 - mae: 0.1172 - val_loss: 0.0147 - val_mae: 0.0953
# Epoch 824/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: 0.0215 - mae: 0.1117 - val_loss: 0.0136 - val_mae: 0.0905
# Epoch 825/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0234 - mae: 0.1188 - val_loss: 0.0139 - val_mae: 0.0920
# Epoch 826/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 0.0224 - mae: 0.1158 - val_loss: 0.0146 - val_mae: 0.0951
# Epoch 827/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0213 - mae: 0.1117 - val_loss: 0.0136 - val_mae: 0.0906
# Epoch 828/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 0.0235 - mae: 0.1190 - val_loss: 0.0144 - val_mae: 0.0939
# Epoch 829/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0201 - mae: 0.1086 - val_loss: 0.0169 - val_mae: 0.1032
# Epoch 830/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0228 - mae: 0.1170 - val_loss: 0.0138 - val_mae: 0.0914
# Epoch 831/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.0194 - mae: 0.1079 - val_loss: 0.0160 - val_mae: 0.1004
# Epoch 832/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0226 - mae: 0.1156 - val_loss: 0.0138 - val_mae: 0.0916
# Epoch 833/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0211 - mae: 0.1121 - val_loss: 0.0145 - val_mae: 0.0948
# Epoch 834/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0212 - mae: 0.1115 - val_loss: 0.0136 - val_mae: 0.0905
# Epoch 835/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0235 - mae: 0.1191 - val_loss: 0.0143 - val_mae: 0.0936
# Epoch 836/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.0203 - mae: 0.1088 - val_loss: 0.0174 - val_mae: 0.1046
# Epoch 837/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0230 - mae: 0.1178 - val_loss: 0.0138 - val_mae: 0.0917
# Epoch 838/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0211 - mae: 0.1123 - val_loss: 0.0144 - val_mae: 0.0944
# Epoch 839/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0212 - mae: 0.1117 - val_loss: 0.0137 - val_mae: 0.0908
# Epoch 840/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0233 - mae: 0.1187 - val_loss: 0.0139 - val_mae: 0.0920
# Epoch 841/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0223 - mae: 0.1153 - val_loss: 0.0147 - val_mae: 0.0954
# Epoch 842/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0214 - mae: 0.1115 - val_loss: 0.0137 - val_mae: 0.0907
# Epoch 843/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0232 - mae: 0.1185 - val_loss: 0.0139 - val_mae: 0.0918
# Epoch 844/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0226 - mae: 0.1168 - val_loss: 0.0207 - val_mae: 0.1141
# Epoch 845/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - loss: 0.0236 - mae: 0.1218 - val_loss: 0.0139 - val_mae: 0.0920
# Epoch 846/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0212 - mae: 0.1125 - val_loss: 0.0146 - val_mae: 0.0949
# Epoch 847/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0211 - mae: 0.1113 - val_loss: 0.0138 - val_mae: 0.0913
# Epoch 848/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0223 - mae: 0.1160 - val_loss: 0.0135 - val_mae: 0.0904
# Epoch 849/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0237 - mae: 0.1199 - val_loss: 0.0143 - val_mae: 0.0937
# Epoch 850/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0205 - mae: 0.1093 - val_loss: 0.0165 - val_mae: 0.1019
# Epoch 851/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0227 - mae: 0.1163 - val_loss: 0.0138 - val_mae: 0.0914
# Epoch 852/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0218 - mae: 0.1137 - val_loss: 0.0135 - val_mae: 0.0903
# Epoch 853/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0236 - mae: 0.1198 - val_loss: 0.0139 - val_mae: 0.0919
# Epoch 854/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0226 - mae: 0.1170 - val_loss: 0.0146 - val_mae: 0.0949
# Epoch 855/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0211 - mae: 0.1113 - val_loss: 0.0140 - val_mae: 0.0923
# Epoch 856/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - loss: 0.0210 - mae: 0.1115 - val_loss: 0.0155 - val_mae: 0.0984
# Epoch 857/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.0221 - mae: 0.1135 - val_loss: 0.0137 - val_mae: 0.0908
# Epoch 858/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.0229 - mae: 0.1178 - val_loss: 0.0138 - val_mae: 0.0916
# Epoch 859/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 64ms/step - loss: 0.0228 - mae: 0.1175 - val_loss: 0.0144 - val_mae: 0.0943
# Epoch 860/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - loss: 0.0204 - mae: 0.1087 - val_loss: 0.0145 - val_mae: 0.0946
# Epoch 861/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0219 - mae: 0.1126 - val_loss: 0.0136 - val_mae: 0.0906
# Epoch 862/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0231 - mae: 0.1179 - val_loss: 0.0139 - val_mae: 0.0918
# Epoch 863/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0223 - mae: 0.1160 - val_loss: 0.0144 - val_mae: 0.0942
# Epoch 864/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0193 - mae: 0.1065 - val_loss: 0.0138 - val_mae: 0.0918
# Epoch 865/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0209 - mae: 0.1110 - val_loss: 0.0135 - val_mae: 0.0901
# Epoch 866/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0235 - mae: 0.1193 - val_loss: 0.0141 - val_mae: 0.0926
# Epoch 867/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0211 - mae: 0.1115 - val_loss: 0.0140 - val_mae: 0.0924
# Epoch 868/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0210 - mae: 0.1112 - val_loss: 0.0139 - val_mae: 0.0921
# Epoch 869/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0207 - mae: 0.1101 - val_loss: 0.0141 - val_mae: 0.0931
# Epoch 870/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0217 - mae: 0.1125 - val_loss: 0.0136 - val_mae: 0.0906
# Epoch 871/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0227 - mae: 0.1174 - val_loss: 0.0137 - val_mae: 0.0912
# Epoch 872/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0229 - mae: 0.1178 - val_loss: 0.0141 - val_mae: 0.0928
# Epoch 873/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0198 - mae: 0.1082 - val_loss: 0.0155 - val_mae: 0.0986
# Epoch 874/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0230 - mae: 0.1172 - val_loss: 0.0170 - val_mae: 0.1034
# Epoch 875/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0210 - mae: 0.1128 - val_loss: 0.0170 - val_mae: 0.1035
# Epoch 876/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0212 - mae: 0.1132 - val_loss: 0.0170 - val_mae: 0.1034
# Epoch 877/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0210 - mae: 0.1126 - val_loss: 0.0171 - val_mae: 0.1038
# Epoch 878/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - loss: 0.0211 - mae: 0.1130 - val_loss: 0.0170 - val_mae: 0.1033
# Epoch 879/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.0210 - mae: 0.1125 - val_loss: 0.0170 - val_mae: 0.1036
# Epoch 880/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0210 - mae: 0.1127 - val_loss: 0.0170 - val_mae: 0.1036
# Epoch 881/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 0.0210 - mae: 0.1128 - val_loss: 0.0170 - val_mae: 0.1036
# Epoch 882/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0210 - mae: 0.1128 - val_loss: 0.0170 - val_mae: 0.1036
# Epoch 883/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0209 - mae: 0.1125 - val_loss: 0.0170 - val_mae: 0.1035
# Epoch 884/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0209 - mae: 0.1124 - val_loss: 0.0170 - val_mae: 0.1035
# Epoch 885/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0209 - mae: 0.1123 - val_loss: 0.0170 - val_mae: 0.1034
# Epoch 886/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0209 - mae: 0.1123 - val_loss: 0.0170 - val_mae: 0.1034
# Epoch 887/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - loss: 0.0208 - mae: 0.1123 - val_loss: 0.0169 - val_mae: 0.1034
# Epoch 888/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0208 - mae: 0.1122 - val_loss: 0.0169 - val_mae: 0.1033
# Epoch 889/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0209 - mae: 0.1123 - val_loss: 0.0169 - val_mae: 0.1033
# Epoch 890/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 76ms/step - loss: 0.0208 - mae: 0.1122 - val_loss: 0.0169 - val_mae: 0.1032
# Epoch 891/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 0.0208 - mae: 0.1122 - val_loss: 0.0167 - val_mae: 0.1023
# Epoch 892/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - loss: 0.0203 - mae: 0.1105 - val_loss: 0.0164 - val_mae: 0.1012
# Epoch 893/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 130ms/step - loss: 0.0196 - mae: 0.1089 - val_loss: 0.0163 - val_mae: 0.1009
# Epoch 894/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0195 - mae: 0.1087 - val_loss: 0.0162 - val_mae: 0.1008
# Epoch 895/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0194 - mae: 0.1086 - val_loss: 0.0163 - val_mae: 0.1011
# Epoch 896/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0196 - mae: 0.1090 - val_loss: 0.0163 - val_mae: 0.1011
# Epoch 897/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - loss: 0.0196 - mae: 0.1092 - val_loss: 0.0163 - val_mae: 0.1011
# Epoch 898/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - loss: 0.0196 - mae: 0.1092 - val_loss: 0.0163 - val_mae: 0.1010
# Epoch 899/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0196 - mae: 0.1092 - val_loss: 0.0163 - val_mae: 0.1010
# Epoch 900/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0196 - mae: 0.1093 - val_loss: 0.0163 - val_mae: 0.1009

# %%
# Draw a graph of the loss, which is the distance between
# the predicted and actual values during training and validation.
loss = history_2.history['loss']
val_loss = history_2.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'g.', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Exclude the first few epochs so the graph is easier to read
SKIP = 100
plt.clf()

plt.plot(epochs[SKIP:], loss[SKIP:], 'g.', label='Training loss')
plt.plot(epochs[SKIP:], val_loss[SKIP:], 'b.', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
#Finally, we plot the mean absolute error for the same set of epochs:
plt.clf()
# Draw a graph of mean absolute error, which is another way of
# measuring the amount of error in the prediction.
mae = history_2.history['mae']
val_mae = history_2.history['val_mae']
plt.plot(epochs[SKIP:], mae[SKIP:], 'g.', label='Training MAE')
plt.plot(epochs[SKIP:], val_mae[SKIP:], 'b.', label='Validation MAE')
plt.title('Training and validation mean absolute error')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.show()

# %%
#This cell will evaluate our model against our test data:
# Calculate and print the loss on our test dataset
loss = model_2.evaluate(x_test, y_test)
# Make predictions based on our test dataset
predictions = model_2.predict(x_test)
# Graph the predictions against the actual values
plt.clf()
plt.title('Comparison of predictions and actual values')
plt.plot(x_test, y_test, 'b.', label='Actual')
plt.plot(x_test, predictions, 'r.', label='Predicted')
plt.legend()
plt.show()
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0164 - mae: 0.0996
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step

# %%
# Trying out saving the model in h5 file format
# Ref: https://www.tensorflow.org/tutorials/keras/save_and_load
# We have the model_2 object that needs to be saved
# It save text file with Hex numbers in HDF5 format in the current dir
# This model file has a size of 35 KB
model_2.save('Sine_2L_Model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Converting a tf.Keras model to a TensorFlow Lite model.
converter = tf.lite.TFLiteConverter.from_keras_model(model_2)
tflite_model = converter.convert()
# Out:
# INFO:tensorflow:Assets written to: C:\Users\LENOVO\AppData\Local\Temp\tmpb71s4c6n\assets
# INFO:tensorflow:Assets written to: C:\Users\LENOVO\AppData\Local\Temp\tmpb71s4c6n\assets
# Saved artifact at 'C:\Users\LENOVO\AppData\Local\Temp\tmpb71s4c6n'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 1), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   2107042538960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2107088963536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2107088964304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2107088965840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2107088963920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2107088966032: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
# Save the model in TFlite format whose size is just 5 KB
# It brings down the size from 40 KB to 5 KB, 8 times reduction
with open('Sine_2L_Model.tflite', 'wb') as f:
  f.write(tflite_model)

# %%
# Run the inference on TFLITE model on Python ... here itself first
# Let us now first try to run this tflinte model on Python itself
# Ref: https://www.tensorflow.org/lite/guide/inference
# Load the TFLite model and allocate tensors.
interpreter = tf.lite.Interpreter(model_path="Sine_2L_Model.tflite")
interpreter.allocate_tensors()

# %%
# Get input and output tensors.
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()
print('input_details:\n', input_details)
print('output_details:\n', output_details)
# Out:
# input_details:
#  [{'name': 'serving_default_keras_tensor:0', 'index': 0, 'shape': array([1, 1]), 'shape_signature': array([-1,  1]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]
# output_details:
#  [{'name': 'StatefulPartitionedCall_1:0', 'index': 9, 'shape': array([1, 1]), 'shape_signature': array([-1,  1]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]

# %%
# Test the model on random input data.
input_shape = input_details[0]['shape']
input_data = np.random.random_sample(input_shape)
print(input_data)
input_data = np.array(input_data, dtype=np.float32)
interpreter.set_tensor(input_details[0]['index'], input_data)

interpreter.invoke()

# The function `get_tensor()` returns a copy of the tensor data.
# Use `tensor()` in order to get a pointer to the tensor.
output_data = interpreter.get_tensor(output_details[0]['index'])
print(output_data)
# Out:
# [[0.86388958]]
# [[5.5332074]]

# %%
input_data.shape
# Out:
# (1, 1)

# %%
# Verify if the same data is given to the original model what is the output
output_data = model_2.predict([input_data])
print(output_data)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step
# [[5.533207]]

# %%
#print('x_test', x_test)
out_dat = []
for x_dat in x_test:
    in_dat = [[]]
    in_dat[0].append(x_dat)
#    print('x_dat', x_dat, 'in_dat', in_dat)
#    print('input_data:\n', input_data)
    input_data = np.array(in_dat, dtype=np.float32)
    interpreter.set_tensor(input_details[0]['index'], input_data)
    interpreter.invoke()
    output_data = interpreter.get_tensor(output_details[0]['index'])
    out_dat.append(list(output_data[0]))

print(output_data[0][0])
print(out_dat)
# Out:
# 4.7802467
# Graph the predictions against the actual values
plt.clf()
plt.title('Comparison of predictions from TFLite model and actual values')
plt.plot(x_test, y_test, 'b.', label='Actual')
plt.plot(x_test, out_dat, 'r.', label='Predicted')
plt.legend()
plt.show()

# %%
ARENA_BLK_SIZE = 1024

# Function to convert some hex values into an array for C programming
def     dump_tflite_hex(file_name, tflite_model, c_str):

    model_len = len(tflite_model)
    # Add array length at the top of the file
    c_str += '\nunsigned int ' + file_name + '_len = ' + str(model_len) + ';\n\n'

    c_str += '// Since the size is ' + str(model_len)
    c_str += ' for this model the Tensor arena size needs to be\n'
    c_str += '#define TENSOR_ARENA_SIZE ' \
                + str(((model_len//ARENA_BLK_SIZE) + 1)//2) \
                + '*1024\n\n'

    # Declare C variable
    c_str += 'unsigned char ' + file_name + '[] = {'
    hex_array = []
    for i, val in enumerate(tflite_model):
        # Construct string from hex
        hex_str = format(val, '#04x')

        # Add formating so each line stays within 80 characters
        if (i + 1) < len(tflite_model):
          hex_str += ','
        if (i + 1) % 12 == 0:
          hex_str += '\n'
        hex_array.append(hex_str)

    # Add closing brace
    c_str += '\n' + format(''.join(hex_array)) + '\n};\n\n'

    return c_str

# %%
# Function to convert some hex values into an array for C programming
import time, sys

def hex_to_c_array(tflite_model, file_name):
    c_str = ""

    # Create header guard
    c_str += '#ifndef ' + file_name.upper() + '_H\n'
    c_str += "#define " + file_name.upper() + '_H\n\n'

    c_str += "/*\n Author: Mouli Sankaran \n"
    c_str += " CAUTION: This is an auto generated file.\n DO NOT EDIT OR MAKE ANY CHANGES TO IT.\n"

# Time stamping of this model data in the generated file
    localtime = time.asctime( time.localtime(time.time()) )
    c_str += " This model data was generated on " + localtime+ '\n\n'
    print("This model data was generated on:", localtime)

# Add information about the verisons of tools and packages used in generating this header file
    c_str += " Tools used:\n Python:" + str(sys.version) + "\n Numpy:" + str(np.version.version) + \
          "\n TensorFlow:" + str(tf.__version__) + "\n Keras: "+ str(tf.keras.__version__) + "\n\n"
    print("Tools used: Python:", sys.version, "\n Numpy:", np.version.version, \
          "\n TensorFlow:", tf.__version__, "\n Keras: ", tf.keras.__version__, "\n\n")

# Training details of the model
    c_str += ' Model details are:\n'
    c_str += ' NUM_OF_EPOCHS = ' + str(NUM_OF_EPOCHS) + '\n'
    c_str += ' BATCH_SIZE    = ' + str(BATCH_SIZE) + '\n*/\n'

# Generate 'C' constants for the no. of nodes in each layer
    c_str += '\nconst int ' + 'DENSE1_SIZE' + ' = ' + str(DENSE1_SIZE) + ';\n'
    c_str +=   'const int ' + 'DENSE2_SIZE' + ' = ' + str(DENSE2_SIZE) + ';\n'

    c_str = dump_tflite_hex(file_name, tflite_model, c_str)

# Close out header guard
    c_str += '#endif //' + file_name.upper() + '_H'

    return c_str

# %%
# Write TFLite model to a C source (or header) file
with open("sine_2L_model_tflite" + '.h', 'w') as file:
    file.write(hex_to_c_array(tflite_model, "sine_2L_model_tflite"))
# Out:
# This model data was generated on: Mon Sep 30 12:08:38 2024
# Tools used: Python: 3.11.5 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:26:23) [MSC v.1916 64 bit (AMD64)]
#  Numpy: 1.24.3
#  TensorFlow: 2.17.0
#  Keras:  3.5.0
