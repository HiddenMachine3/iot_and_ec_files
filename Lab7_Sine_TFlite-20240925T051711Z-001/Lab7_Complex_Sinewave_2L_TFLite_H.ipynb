# %%
# TensorFlow is an open source machine learning library
import tensorflow as tf

# NumPy is a math library
import numpy as np

# Matplotlib is a graphing library
import matplotlib.pyplot as plt

# math is Python's math library
import math

# We'll use Keras to create a simple model architecture
# Note: Changed tf.keras below to tensorflow.keras (code from the book)
from tensorflow.keras import layers

# Define the number of nodes in each layer of the network
# Layer1 with 24 and Layer2 with 16 nodes is better than 16 and 24 respectively.
DENSE1_SIZE = 32
DENSE2_SIZE = 16
NUM_OF_EPOCHS = 900  # Changed 1500 to 900 because no change in loss after 800
BATCH_SIZE = 16

# We'll generate this many sample datapoints
SAMPLES = 1200
# Set a "seed" value, so we get the same random numbers each time we run this
# notebook. Any number can be used here.
SEED = 1337
np.random.seed(SEED)
tf.random.set_seed(SEED)
# Generate a uniformly distributed set of random numbers in the range from
# 0 to 2π, which covers a complete sine wave oscillation
# You can generate only a half of the sine wave by changing high from 2pi to pi
x_values = np.random.uniform(low=0, high=2 * math.pi, size=SAMPLES)
# Shuffle the values to guarantee they're not in order
np.random.shuffle(x_values)
# Calculate the corresponding sine values
y_values = 5 * np.sin(x_values) ** 2 + 4 * np.cos(x_values)  # np.sin(x_values)
# Plot our data. The 'b.' argument tells the library to print blue dots.
plt.plot(x_values, y_values, "b.")
plt.show()

# Add a small random number to each y value
# When the number of Layer 1 and 2 nodes are increased, the noise level
# from 0.001 to some higher value (0.01, etc) still impacts less the quality
# of predictions.
y_values += 0.1 * np.random.randn(*y_values.shape)
# Plot our data
plt.plot(x_values, y_values, "b.")
plt.show()

# We'll use 60% of our data for training and 20% for testing. The remaining 20%
# will be used for validation. Calculate the indices of each section.
TRAIN_SPLIT = int(0.6 * SAMPLES)
TEST_SPLIT = int(0.2 * SAMPLES + TRAIN_SPLIT)
# Use np.split to chop our data into three parts.
# The second argument to np.split is an array of indices where the data will be
# split. We provide two indices, so the data will be divided into three chunks.
x_train, x_validate, x_test = np.split(x_values, [TRAIN_SPLIT, TEST_SPLIT])
y_train, y_validate, y_test = np.split(y_values, [TRAIN_SPLIT, TEST_SPLIT])
# Double check that our splits add up correctly
assert (x_train.size + x_validate.size + x_test.size) == SAMPLES

# Plot the data in each partition in different colors:
plt.plot(x_train, y_train, "b.", label="Train")
plt.plot(x_validate, y_validate, "y.", label="Validate")
plt.plot(x_test, y_test, "r.", label="Test")
plt.legend()
plt.show()


# Activation function used here is relu (Rectified Linear Unit)
def relu(input):
    return max(0.0, input)


model_2 = tf.keras.Sequential()
# First layer takes a scalar input and feeds it through 16 "neurons." The
# neurons decide whether to activate based on the 'relu' activation function.
model_2.add(layers.Dense(DENSE1_SIZE, activation="relu", input_shape=(1,)))
# The new second layer may help the network learn more complex representations
model_2.add(layers.Dense(DENSE2_SIZE, activation="relu"))
# Final layer is a single neuron, since we want to output a single value
model_2.add(layers.Dense(1))
# Compile the model using a standard optimizer and loss function for regression
model_2.compile(optimizer="rmsprop", loss="mse", metrics=["mae"])
# Show a summary of the model
model_2.summary()
# Out:
# d:\opt\WingetApps_Ddrive\anaconda\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 32)             │            64 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 609 (2.38 KB)
#  Trainable params: 609 (2.38 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# 0. Did not get the same accurate predection as shown in the book epochs=600
# 1. So, increased the epochs from 600 to 1000 to see if there is any improvement
# Saw a great improvment on the negative cycle, which was closer to actual
# 2. Increased the epochs still further from 1000 to 1200 to see if it improves further
# 3. Still some error near negative peak, so changed it from 1200 to 1500
# 4. So far, the batch size was kept at 16. Now epochs=1500 and batch_size=32 tried out
# The previous run +v peak also got affected a bit, but -ve peak became better
# 5. Change now epochs=1500 and batch_size=64, it became worse.
# 6. Went back to epochs=1500 and batch_size=16
# 7. Error does not improve beyond Epoch=1000, so reduced it from 1500 to 1000
history_2 = model_2.fit(x_train, y_train, epochs=NUM_OF_EPOCHS, batch_size=BATCH_SIZE,
validation_data=(x_validate, y_validate))
# Out:
# Epoch 1/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 16.7101 - mae: 3.8019 - val_loss: 12.6085 - val_mae: 3.2908
# Epoch 2/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12.4949 - mae: 3.2172 - val_loss: 11.4172 - val_mae: 3.0440
# Epoch 3/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 11.6695 - mae: 3.0144 - val_loss: 11.2357 - val_mae: 2.9932
# Epoch 4/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.4465 - mae: 2.9697 - val_loss: 11.1573 - val_mae: 2.9846
# Epoch 5/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 11.2815 - mae: 2.9507 - val_loss: 11.0936 - val_mae: 2.9806
# Epoch 6/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.1282 - mae: 2.9346 - val_loss: 11.0379 - val_mae: 2.9782
# Epoch 7/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.9828 - mae: 2.9192 - val_loss: 10.9890 - val_mae: 2.9762
# Epoch 8/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.8446 - mae: 2.9042 - val_loss: 10.9470 - val_mae: 2.9746
# Epoch 9/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.7137 - mae: 2.8894 - val_loss: 10.9127 - val_mae: 2.9734
# Epoch 10/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 10.5906 - mae: 2.8753 - val_loss: 10.8856 - val_mae: 2.9727
# Epoch 11/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 10.4765 - mae: 2.8618 - val_loss: 10.8652 - val_mae: 2.9721
# Epoch 12/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.3712 - mae: 2.8486 - val_loss: 10.8517 - val_mae: 2.9718
# Epoch 13/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 10.2754 - mae: 2.8362 - val_loss: 10.8439 - val_mae: 2.9715
# Epoch 14/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.1889 - mae: 2.8243 - val_loss: 10.8416 - val_mae: 2.9714
# Epoch 15/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 10.1115 - mae: 2.8129 - val_loss: 10.8441 - val_mae: 2.9715
# Epoch 16/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.0433 - mae: 2.8023 - val_loss: 10.8504 - val_mae: 2.9718
# Epoch 17/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.9836 - mae: 2.7924 - val_loss: 10.8599 - val_mae: 2.9723
# Epoch 18/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.9319 - mae: 2.7832 - val_loss: 10.8718 - val_mae: 2.9727
# Epoch 19/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.8873 - mae: 2.7746 - val_loss: 10.8854 - val_mae: 2.9731
# Epoch 20/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.8493 - mae: 2.7668 - val_loss: 10.9000 - val_mae: 2.9733
# Epoch 21/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.8170 - mae: 2.7596 - val_loss: 10.9152 - val_mae: 2.9735
# Epoch 22/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.7898 - mae: 2.7530 - val_loss: 10.9303 - val_mae: 2.9735
# Epoch 23/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.7667 - mae: 2.7469 - val_loss: 10.9451 - val_mae: 2.9736
# Epoch 24/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.7475 - mae: 2.7415 - val_loss: 10.9590 - val_mae: 2.9735
# Epoch 25/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7312 - mae: 2.7366 - val_loss: 10.9723 - val_mae: 2.9734
# Epoch 26/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7176 - mae: 2.7322 - val_loss: 10.9847 - val_mae: 2.9734
# Epoch 27/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.7064 - mae: 2.7283 - val_loss: 10.9959 - val_mae: 2.9732
# Epoch 28/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.6968 - mae: 2.7248 - val_loss: 11.0061 - val_mae: 2.9730
# Epoch 29/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.6887 - mae: 2.7216 - val_loss: 11.0154 - val_mae: 2.9728
# Epoch 30/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.6818 - mae: 2.7189 - val_loss: 11.0237 - val_mae: 2.9727
# Epoch 31/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.6761 - mae: 2.7164 - val_loss: 11.0312 - val_mae: 2.9726
# Epoch 32/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.6712 - mae: 2.7143 - val_loss: 11.0377 - val_mae: 2.9724
# Epoch 33/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6671 - mae: 2.7124 - val_loss: 11.0434 - val_mae: 2.9723
# Epoch 34/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.6634 - mae: 2.7107 - val_loss: 11.0484 - val_mae: 2.9721
# Epoch 35/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.6602 - mae: 2.7091 - val_loss: 11.0528 - val_mae: 2.9719
# Epoch 36/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.6575 - mae: 2.7078 - val_loss: 11.0567 - val_mae: 2.9718
# Epoch 37/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6552 - mae: 2.7066 - val_loss: 11.0600 - val_mae: 2.9716
# Epoch 38/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6531 - mae: 2.7055 - val_loss: 11.0629 - val_mae: 2.9715
# Epoch 39/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6514 - mae: 2.7046 - val_loss: 11.0656 - val_mae: 2.9713
# Epoch 40/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.
900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.3200 - mae: 2.0525 - val_loss: 7.4782 - val_mae: 2.3680
# Epoch 303/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1684 - mae: 2.0263 - val_loss: 7.2953 - val_mae: 2.3412
# Epoch 304/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0139 - mae: 1.9993 - val_loss: 7.1088 - val_mae: 2.3130
# Epoch 305/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.8566 - mae: 1.9714 - val_loss: 6.9189 - val_mae: 2.2835
# Epoch 306/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.6962 - mae: 1.9423 - val_loss: 6.7215 - val_mae: 2.2516
# Epoch 307/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.5333 - mae: 1.9126 - val_loss: 6.5234 - val_mae: 2.2192
# Epoch 308/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3678 - mae: 1.8819 - val_loss: 6.3207 - val_mae: 2.1844
# Epoch 309/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2032 - mae: 1.8511 - val_loss: 6.1142 - val_mae: 2.1480
# Epoch 310/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0337 - mae: 1.8180 - val_loss: 5.9056 - val_mae: 2.1103
# Epoch 311/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8632 - mae: 1.7848 - val_loss: 5.6982 - val_mae: 2.0727
# Epoch 312/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6935 - mae: 1.7532 - val_loss: 5.4876 - val_mae: 2.0331
# Epoch 313/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.5211 - mae: 1.7213 - val_loss: 5.2771 - val_mae: 1.9923
# Epoch 314/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3502 - mae: 1.6897 - val_loss: 5.0689 - val_mae: 1.9499
# Epoch 315/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1805 - mae: 1.6582 - val_loss: 4.8570 - val_mae: 1.9045
# Epoch 316/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0149 - mae: 1.6277 - val_loss: 4.6546 - val_mae: 1.8609
# Epoch 317/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.8534 - mae: 1.5980 - val_loss: 4.4592 - val_mae: 1.8213
# Epoch 318/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6923 - mae: 1.5680 - val_loss: 4.2693 - val_mae: 1.7815
# Epoch 319/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5358 - mae: 1.5385 - val_loss: 4.0844 - val_mae: 1.7411
# Epoch 320/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3840 - mae: 1.5088 - val_loss: 3.9038 - val_mae: 1.7000
# Epoch 321/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2382 - mae: 1.4796 - val_loss: 3.7307 - val_mae: 1.6594
# Epoch 322/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0995 - mae: 1.4518 - val_loss: 3.5622 - val_mae: 1.6189
# Epoch 323/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9679 - mae: 1.4246 - val_loss: 3.4039 - val_mae: 1.5793
# Epoch 324/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8438 - mae: 1.3974 - val_loss: 3.2526 - val_mae: 1.5392
# Epoch 325/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7275 - mae: 1.3702 - val_loss: 3.1096 - val_mae: 1.5013
# Epoch 326/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6208 - mae: 1.3449 - val_loss: 2.9742 - val_mae: 1.4637
# Epoch 327/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5215 - mae: 1.3189 - val_loss: 2.8453 - val_mae: 1.4264
# Epoch 328/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.4302 - mae: 1.2930 - val_loss: 2.7265 - val_mae: 1.3892
# Epoch 329/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3455 - mae: 1.2664 - val_loss: 2.6159 - val_mae: 1.3528
# Epoch 330/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2682 - mae: 1.2400 - val_loss: 2.5141 - val_mae: 1.3172
# Epoch 331/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1985 - mae: 1.2141 - val_loss: 2.4208 - val_mae: 1.2820
# Epoch 332/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1362 - mae: 1.1887 - val_loss: 2.3354 - val_mae: 1.2475
# Epoch 333/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0802 - mae: 1.1632 - val_loss: 2.2576 - val_mae: 1.2142
# Epoch 334/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0309 - mae: 1.1382 - val_loss: 2.1866 - val_mae: 1.1821
# Epoch 335/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.
900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5261 - mae: 0.5305 - val_loss: 0.4881 - val_mae: 0.5156
# Epoch 402/900
# ...
# Epoch 767/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0633 - mae: 0.1832 - val_loss: 0.0720 - val_mae: 0.1876
# Epoch 768/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0632 - mae: 0.1832 - val_loss: 0.0718 - val_mae: 0.1874
# Epoch 769/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0631 - mae: 0.1830 - val_loss: 0.0717 - val_mae: 0.1873
# Epoch 770/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0630 - mae: 0.1830 - val_loss: 0.0716 - val_mae: 0.1871
# Epoch 771/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0629 - mae: 0.1828 - val_loss: 0.0715 - val_mae: 0.1870
# Epoch 772/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0629 - mae: 0.1827 - val_loss: 0.0713 - val_mae: 0.1868
# Epoch 773/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0628 - mae: 0.1825 - val_loss: 0.0712 - val_mae: 0.1867
# Epoch 774/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0627 - mae: 0.1825 - val_loss: 0.0711 - val_mae: 0.1864
# Epoch 775/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0626 - mae: 0.1823 - val_loss: 0.0710 - val_mae: 0.1863
# Epoch 776/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0625 - mae: 0.1822 - val_loss: 0.0708 - val_mae: 0.1861
# Epoch 777/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0624 - mae: 0.1820 - val_loss: 0.0707 - val_mae: 0.1860
# Epoch 778/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0624 - mae: 0.1820 - val_loss: 0.0705 - val_mae: 0.1858
# Epoch 779/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0622 - mae: 0.1817 - val_loss: 0.0704 - val_mae: 0.1857
# Epoch 780/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0622 - mae: 0.1817 - val_loss: 0.0702 - val_mae: 0.1854
# Epoch 781/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0620 - mae: 0.1815 - val_loss: 0.0701 - val_mae: 0.1853
# Epoch 782/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0620 - mae: 0.1815 - val_loss: 0.0700 - val_mae: 0.1850
# Epoch 783/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0619 - mae: 0.1813 - val_loss: 0.0699 - val_mae: 0.1849
# Epoch 784/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0618 - mae: 0.1812 - val_loss: 0.0696 - val_mae: 0.1848
# Epoch 785/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0617 - mae: 0.1811 - val_loss: 0.0696 - val_mae: 0.1846
# Epoch 786/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0617 - mae: 0.1810 - val_loss: 0.0694 - val_mae: 0.1843
# Epoch 787/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0615 - mae: 0.1808 - val_loss: 0.0693 - val_mae: 0.1842
# Epoch 788/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0615 - mae: 0.1807 - val_loss: 0.0691 - val_mae: 0.1841
# Epoch 789/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0614 - mae: 0.1806 - val_loss: 0.0690 - val_mae: 0.1839
# Epoch 790/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0613 - mae: 0.1805 - val_loss: 0.0689 - val_mae: 0.1836
# Epoch 791/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0612 - mae: 0.1802 - val_loss: 0.0687 - val_mae: 0.1836
# Epoch 792/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0612 - mae: 0.1803 - val_loss: 0.0686 - val_mae: 0.1833
# Epoch 793/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0610 - mae: 0.1801 - val_loss: 0.0684 - val_mae: 0.1833
# Epoch 794/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0610 - mae: 0.1800 - val_loss: 0.0683 - val_mae: 0.1829
# Epoch 795/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0608 - mae: 0.1797 - val_loss: 0.0681 - val_mae: 0.1828
# Epoch 796/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0608 - mae: 0.1798 - val_loss: 0.0680 - val_mae: 0.1825
# Epoch 797/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0607 - mae: 0.1795 - val_loss: 0.0679 - val_mae: 0.1823
# Epoch 798/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0606 - mae: 0.1794 - val_loss: 0.0677 - val_mae: 0.1823
# Epoch 799/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0606 - mae: 0.1794 - val_loss: 0.0676 - val_mae: 0.1820
# Epoch 800/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0604 - mae: 0.1792 - val_loss: 0.0674 - val_mae: 0.1818
# Epoch 801/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0603 - mae: 0.1790 - val_loss: 0.0673 - val_mae: 0.1816
# Epoch 802/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0602 - mae: 0.1789 - val_loss: 0.0671 - val_mae: 0.1815
# Epoch 803/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0602 - mae: 0.1788 - val_loss: 0.0671 - val_mae: 0.1812
# Epoch 804/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0601 - mae: 0.1787 - val_loss: 0.0668 - val_mae: 0.1810
# Epoch 805/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0600 - mae: 0.1785 - val_loss: 0.0668 - val_mae: 0.1808
# Epoch 806/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0599 - mae: 0.1784 - val_loss: 0.0666 - val_mae: 0.1806
# Epoch 807/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0598 - mae: 0.1783 - val_loss: 0.0664 - val_mae: 0.1805
# Epoch 808/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0598 - mae: 0.1782 - val_loss: 0.0663 - val_mae: 0.1802
# Epoch 809/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0596 - mae: 0.1779 - val_loss: 0.0661 - val_mae: 0.1802
# Epoch 810/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0596 - mae: 0.1779 - val_loss: 0.0660 - val_mae: 0.1799
# Epoch 811/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0594 - mae: 0.1778 - val_loss: 0.0659 - val_mae: 0.1798
# Epoch 812/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0594 - mae: 0.1777 - val_loss: 0.0657 - val_mae: 0.1794
# Epoch 813/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0592 - mae: 0.1774 - val_loss: 0.0656 - val_mae: 0.1794
# Epoch 814/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0592 - mae: 0.1774 - val_loss: 0.0655 - val_mae: 0.1792
# Epoch 815/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0591 - mae: 0.1772 - val_loss: 0.0652 - val_mae: 0.1790
# Epoch 816/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0590 - mae: 0.1770 - val_loss: 0.0651 - val_mae: 0.1788
# Epoch 817/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0589 - mae: 0.1769 - val_loss: 0.0649 - val_mae: 0.1786
# Epoch 818/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0588 - mae: 0.1767 - val_loss: 0.0649 - val_mae: 0.1783
# Epoch 819/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0587 - mae: 0.1766 - val_loss: 0.0648 - val_mae: 0.1781
# Epoch 820/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0587 - mae: 0.1765 - val_loss: 0.0646 - val_mae: 0.1780
# Epoch 821/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0586 - mae: 0.1764 - val_loss: 0.0645 - val_mae: 0.1777
# Epoch 822/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0585 - mae: 0.1762 - val_loss: 0.0642 - val_mae: 0.1773
# Epoch 823/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0583 - mae: 0.1760 - val_loss: 0.0641 - val_mae: 0.1773
# Epoch 824/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0583 - mae: 0.1760 - val_loss: 0.0640 - val_mae: 0.1771
# Epoch 825/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0582 - mae: 0.1759 - val_loss: 0.0638 - val_mae: 0.1769
# Epoch 826/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0581 - mae: 0.1757 - val_loss: 0.0636 - val_mae: 0.1766
# Epoch 827/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0579 - mae: 0.1754 - val_loss: 0.0635 - val_mae: 0.1764
# Epoch 828/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0579 - mae: 0.1753 - val_loss: 0.0634 - val_mae: 0.1762
# Epoch 829/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0578 - mae: 0.1752 - val_loss: 0.0632 - val_mae: 0.1759
# Epoch 830/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0576 - mae: 0.1749 - val_loss: 0.0631 - val_mae: 0.1758
# Epoch 831/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0576 - mae: 0.1748 - val_loss: 0.0629 - val_mae: 0.1756
# Epoch 832/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0575 - mae: 0.1747 - val_loss: 0.0627 - val_mae: 0.1753
# Epoch 833/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0573 - mae: 0.1744 - val_loss: 0.0626 - val_mae: 0.1752
# Epoch 834/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0572 - mae: 0.1744 - val_loss: 0.0624 - val_mae: 0.1749
# Epoch 835/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0571 - mae: 0.1741 - val_loss: 0.0623 - val_mae: 0.1747
# Epoch 836/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0571 - mae: 0.1741 - val_loss: 0.0621 - val_mae: 0.1744
# Epoch 837/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0569 - mae: 0.1738 - val_loss: 0.0620 - val_mae: 0.1743
# Epoch 838/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0569 - mae: 0.1738 - val_loss: 0.0618 - val_mae: 0.1741
# Epoch 839/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0568 - mae: 0.1737 - val_loss: 0.0617 - val_mae: 0.1738
# Epoch 840/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0567 - mae: 0.1735 - val_loss: 0.0615 - val_mae: 0.1737
# Epoch 841/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0566 - mae: 0.1734 - val_loss: 0.0614 - val_mae: 0.1734
# Epoch 842/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0565 - mae: 0.1732 - val_loss: 0.0613 - val_mae: 0.1733
# Epoch 843/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0564 - mae: 0.1731 - val_loss: 0.0610 - val_mae: 0.1730
# Epoch 844/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0563 - mae: 0.1729 - val_loss: 0.0609 - val_mae: 0.1728
# Epoch 845/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0562 - mae: 0.1728 - val_loss: 0.0607 - val_mae: 0.1726
# Epoch 846/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0561 - mae: 0.1727 - val_loss: 0.0607 - val_mae: 0.1725
# Epoch 847/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0560 - mae: 0.1726 - val_loss: 0.0605 - val_mae: 0.1722
# Epoch 848/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0559 - mae: 0.1724 - val_loss: 0.0603 - val_mae: 0.1720
# Epoch 849/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0558 - mae: 0.1723 - val_loss: 0.0602 - val_mae: 0.1718
# Epoch 850/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0557 - mae: 0.1721 - val_loss: 0.0601 - val_mae: 0.1717
# Epoch 851/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0556 - mae: 0.1720 - val_loss: 0.0599 - val_mae: 0.1714
# Epoch 852/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0555 - mae: 0.1719 - val_loss: 0.0597 - val_mae: 0.1712
# Epoch 853/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0555 - mae: 0.1718 - val_loss: 0.0596 - val_mae: 0.1711
# Epoch 854/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0552 - mae: 0.1714 - val_loss: 0.0595 - val_mae: 0.1711
# Epoch 855/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0551 - mae: 0.1711 - val_loss: 0.0594 - val_mae: 0.1710
# Epoch 856/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0549 - mae: 0.1708 - val_loss: 0.0593 - val_mae: 0.1708
# Epoch 857/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0548 - mae: 0.1705 - val_loss: 0.0592 - val_mae: 0.1707
# Epoch 858/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0547 - mae: 0.1704 - val_loss: 0.0591 - val_mae: 0.1705
# Epoch 859/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0546 - mae: 0.1702 - val_loss: 0.0589 - val_mae: 0.1703
# Epoch 860/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0545 - mae: 0.1700 - val_loss: 0.0587 - val_mae: 0.1701
# Epoch 861/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0543 - mae: 0.1698 - val_loss: 0.0587 - val_mae: 0.1700
# Epoch 862/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0543 - mae: 0.1698 - val_loss: 0.0584 - val_mae: 0.1695
# Epoch 863/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0542 - mae: 0.1696 - val_loss: 0.0584 - val_mae: 0.1696
# Epoch 864/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0541 - mae: 0.1695 - val_loss: 0.0581 - val_mae: 0.1691
# Epoch 865/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0539 - mae: 0.1693 - val_loss: 0.0579 - val_mae: 0.1689
# Epoch 866/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0539 - mae: 0.1692 - val_loss: 0.0578 - val_mae: 0.1687
# Epoch 867/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0538 - mae: 0.1691 - val_loss: 0.0515 - val_mae: 0.1630
# Epoch 868/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0531 - mae: 0.1680 - val_loss: 0.0509 - val_mae: 0.1625
# Epoch 869/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0531 - mae: 0.1684 - val_loss: 0.0507 - val_mae: 0.1629
# Epoch 870/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0531 - mae: 0.1684 - val_loss: 0.0493 - val_mae: 0.1618
# Epoch 871/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0522 - mae: 0.1671 - val_loss: 0.0489 - val_mae: 0.1614
# Epoch 872/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0522 - mae: 0.1669 - val_loss: 0.0488 - val_mae: 0.1611
# Epoch 873/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0521 - mae: 0.1667 - val_loss: 0.0485 - val_mae: 0.1603
# Epoch 874/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0521 - mae: 0.1667 - val_loss: 0.0483 - val_mae: 0.1601
# Epoch 875/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0519 - mae: 0.1664 - val_loss: 0.0481 - val_mae: 0.1597
# Epoch 876/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0519 - mae: 0.1664 - val_loss: 0.0480 - val_mae: 0.1595
# Epoch 877/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0517 - mae: 0.1660 - val_loss: 0.0478 - val_mae: 0.1592
# Epoch 878/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0518 - mae: 0.1662 - val_loss: 0.0478 - val_mae: 0.1594
# Epoch 879/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0516 - mae: 0.1658 - val_loss: 0.0477 - val_mae: 0.1592
# Epoch 880/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0515 - mae: 0.1658 - val_loss: 0.0477 - val_mae: 0.1592
# Epoch 881/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0516 - mae: 0.1659 - val_loss: 0.0476 - val_mae: 0.1590
# Epoch 882/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0515 - mae: 0.1657 - val_loss: 0.0474 - val_mae: 0.1586
# Epoch 883/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0513 - mae: 0.1655 - val_loss: 0.0473 - val_mae: 0.1583
# Epoch 884/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0512 - mae: 0.1653 - val_loss: 0.0471 - val_mae: 0.1580
# Epoch 885/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0510 - mae: 0.1650 - val_loss: 0.0469 - val_mae: 0.1577
# Epoch 886/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0509 - mae: 0.1649 - val_loss: 0.0468 - val_mae: 0.1575
# Epoch 887/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0508 - mae: 0.1646 - val_loss: 0.0467 - val_mae: 0.1572
# Epoch 888/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0507 - mae: 0.1645 - val_loss: 0.0465 - val_mae: 0.1570
# Epoch 889/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0505 - mae: 0.1643 - val_loss: 0.0464 - val_mae: 0.1567
# Epoch 890/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0505 - mae: 0.1641 - val_loss: 0.0462 - val_mae: 0.1564
# Epoch 891/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0503 - mae: 0.1639 - val_loss: 0.0461 - val_mae: 0.1561
# Epoch 892/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0502 - mae: 0.1637 - val_loss: 0.0459 - val_mae: 0.1559
# Epoch 893/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0501 - mae: 0.1635 - val_loss: 0.0458 - val_mae: 0.1556
# Epoch 894/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0500 - mae: 0.1633 - val_loss: 0.0456 - val_mae: 0.1554
# Epoch 895/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0499 - mae: 0.1631 - val_loss: 0.0455 - val_mae: 0.1551
# Epoch 896/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0498 - mae: 0.1630 - val_loss: 0.0453 - val_mae: 0.1549
# Epoch 897/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0497 - mae: 0.1628 - val_loss: 0.0452 - val_mae: 0.1546
# Epoch 898/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0496 - mae: 0.1626 - val_loss: 0.0451 - val_mae: 0.1543
# Epoch 899/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0495 - mae: 0.1625 - val_loss: 0.0449 - val_mae: 0.1541
# Epoch 900/900
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0494 - mae: 0.1623 - val_loss: 0.0448 - val_mae: 0.1539

# %%
# Draw a graph of the loss, which is the distance between
# the predicted and actual values during training and validation.
loss = history_2.history['loss']
val_loss = history_2.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'g.', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Exclude the first few epochs so the graph is easier to read
SKIP = 100
plt.clf()

plt.plot(epochs[SKIP:], loss[SKIP:], 'g.', label='Training loss')
plt.plot(epochs[SKIP:], val_loss[SKIP:], 'b.', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
#Finally, we plot the mean absolute error for the same set of epochs:
plt.clf()
# Draw a graph of mean absolute error, which is another way of
# measuring the amount of error in the prediction.
mae = history_2.history['mae']
val_mae = history_2.history['val_mae']
plt.plot(epochs[SKIP:], mae[SKIP:], 'g.', label='Training MAE')
plt.plot(epochs[SKIP:], val_mae[SKIP:], 'b.', label='Validation MAE')
plt.title('Training and validation mean absolute error')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.show()

# %%
#This cell will evaluate our model against our test data:
# Calculate and print the loss on our test dataset
loss = model_2.evaluate(x_test, y_test)
# Make predictions based on our test dataset
predictions = model_2.predict(x_test)
# Graph the predictions against the actual values
plt.clf()
plt.title('Comparison of predictions and actual values')
plt.plot(x_test, y_test, 'b.', label='Actual')
plt.plot(x_test, predictions, 'r.', label='Predicted')
plt.legend()
plt.show()
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0797 - mae: 0.1814
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %%
# Trying out saving the model in h5 file format
# Ref: https://www.tensorflow.org/tutorials/keras/save_and_load
# We have the model_2 object that needs to be saved
# It save text file with Hex numbers in HDF5 format in the current dir
# This model file has a size of 35 KB
model_2.save('cmplx_Sine_2L_Model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Converting a tf.Keras model to a TensorFlow Lite model.
converter = tf.lite.TFLiteConverter.from_keras_model(model_2)
tflite_model = converter.convert()
# Out:
# INFO:tensorflow:Assets written to: C:\Users\LENOVO\AppData\Local\Temp\tmpoqsexi30\assets
# INFO:tensorflow:Assets written to: C:\Users\LENOVO\AppData\Local\Temp\tmpoqsexi30\assets
# Saved artifact at 'C:\Users\LENOVO\AppData\Local\Temp\tmpoqsexi30'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 1), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   2557086769680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2557133210640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2557133211408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2557133212944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2557133211024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2557133213136: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
# Save the model in TFlite format whose size is just 5 KB
# It brings down the size from 40 KB to 5 KB, 8 times reduction
with open('cmplx_Sine_2L_Model.tflite', 'wb') as f:
  f.write(tflite_model)

# %%
# Run the inference on TFLITE model on Python ... here itself first
# Let us now first try to run this tflinte model on Python itself
# Ref: https://www.tensorflow.org/lite/guide/inference
# Load the TFLite model and allocate tensors.
interpreter = tf.lite.Interpreter(model_path="cmplx_Sine_2L_Model.tflite")
interpreter.allocate_tensors()

# %%
# Get input and output tensors.
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()
print('input_details:\n', input_details)
print('output_details:\n', output_details)
# Out:
# input_details:
#  [{'name': 'serving_default_keras_tensor:0', 'index': 0, 'shape': array([1, 1]), 'shape_signature': array([-1,  1]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]
# output_details:
#  [{'name': 'StatefulPartitionedCall_1:0', 'index': 9, 'shape': array([1, 1]), 'shape_signature': array([-1,  1]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]

# %%
# Test the model on random input data.
input_shape = input_details[0]['shape']
input_data = np.random.random_sample(input_shape)
print(input_data)
input_data = np.array(input_data, dtype=np.float32)
interpreter.set_tensor(input_details[0]['index'], input_data)

interpreter.invoke()

# The function `get_tensor()` returns a copy of the tensor data.
# Use `tensor()` in order to get a pointer to the tensor.
output_data = interpreter.get_tensor(output_details[0]['index'])
print(output_data)
# Out:
# [[0.86388958]]
# [[5.492443]]

# %%
input_data.shape
# Out:
# (1, 1)

# %%
# Verify if the same data is given to the original model what is the output
output_data = model_2.predict([input_data])
print(output_data)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 534ms/step
# [[5.492442]]

# %%
#print('x_test', x_test)
out_dat = []
for x_dat in x_test:
    in_dat = [[]]
    in_dat[0].append(x_dat)
#    print('x_dat', x_dat, 'in_dat', in_dat)
#    print('input_data:\n', input_data)
    input_data = np.array(in_dat, dtype=np.float32)
    interpreter.set_tensor(input_details[0]['index'], input_data)
    interpreter.invoke()
    output_data = interpreter.get_tensor(output_details[0]['index'])
    out_dat.append(list(output_data[0]))

print(output_data[0][0])
print(out_dat)
# Out:
# 4.7624464
# Graph the predictions against the actual values
plt.clf()
plt.title('Comparison of predictions from TFLite model and actual values')
plt.plot(x_test, y_test, 'b.', label='Actual')
plt.plot(x_test, out_dat, 'r.', label='Predicted')
plt.legend()
plt.show()

# %%
ARENA_BLK_SIZE = 1024

# Function to convert some hex values into an array for C programming
def     dump_tflite_hex(file_name, tflite_model, c_str):

    model_len = len(tflite_model)
    # Add array length at the top of the file
    c_str += '\nunsigned int ' + file_name + '_len = ' + str(model_len) + ';\n\n'

    c_str += '// Since the size is ' + str(model_len)
    c_str += ' for this model the Tensor arena size needs to be\n'
    c_str += '#define TENSOR_ARENA_SIZE ' \
                + str(((model_len//ARENA_BLK_SIZE) + 1)//2) \
                + '*1024\n\n'

    # Declare C variable
    c_str += 'unsigned char ' + file_name + '[] = {'
    hex_array = []
    for i, val in enumerate(tflite_model):
        # Construct string from hex
        hex_str = format(val, '#04x')

        # Add formating so each line stays within 80 characters
        if (i + 1) < len(tflite_model):
          hex_str += ','
        if (i + 1) % 12 == 0:
          hex_str += '\n'
        hex_array.append(hex_str)

    # Add closing brace
    c_str += '\n' + format(''.join(hex_array)) + '\n};\n\n'

    return c_str

# %%
# Function to convert some hex values into an array for C programming
import time, sys

def hex_to_c_array(tflite_model, file_name):
    c_str = ""

    # Create header guard
    c_str += '#ifndef ' + file_name.upper() + '_H\n'
    c_str += "#define " + file_name.upper() + '_H\n\n'

    c_str += "/*\n Author: Mouli Sankaran \n"
    c_str += " CAUTION: This is an auto generated file.\n DO NOT EDIT OR MAKE ANY CHANGES TO IT.\n"

# Time stamping of this model data in the generated file
    localtime = time.asctime( time.localtime(time.time()) )
    c_str += " This model data was generated on " + localtime+ '\n\n'
    print("This model data was generated on:", localtime)

# Add information about the verisons of tools and packages used in generating this header file
    c_str += " Tools used:\n Python:" + str(sys.version) + "\n Numpy:" + str(np.version.version) + \
          "\n TensorFlow:" + str(tf.__version__) + "\n Keras: "+ str(tf.keras.__version__) + "\n\n"
    print("Tools used: Python:", sys.version, "\n Numpy:", np.version.version, \
          "\n TensorFlow:", tf.__version__, "\n Keras: ", tf.keras.__version__, "\n\n")

# Training details of the model
    c_str += ' Model details are:\n'
    c_str += ' NUM_OF_EPOCHS = ' + str(NUM_OF_EPOCHS) + '\n'
    c_str += ' BATCH_SIZE    = ' + str(BATCH_SIZE) + '\n*/\n'

# Generate 'C' constants for the no. of nodes in each layer
    c_str += '\nconst int ' + 'DENSE1_SIZE' + ' = ' + str(DENSE1_SIZE) + ';\n'
    c_str +=   'const int ' + 'DENSE2_SIZE' + ' = ' + str(DENSE2_SIZE) + ';\n'

    c_str = dump_tflite_hex(file_name, tflite_model, c_str)

# Close out header guard
    c_str += '#endif //' + file_name.upper() + '_H'

    return c_str

# %%
# Write TFLite model to a C source (or header) file
with open("cmplx_sine_2L_model_tflite" + '.h', 'w') as file:
    file.write(hex_to_c_array(tflite_model, "cmplx_sine_2L_model_tflite"))
# Out:
# This model data was generated on: Thu Oct  3 11:42:55 2024
# Tools used: Python: 3.11.5 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:26:23) [MSC v.1916 64 bit (AMD64)]
#  Numpy: 1.24.3
#  TensorFlow: 2.17.0
#  Keras:  3.5.0
